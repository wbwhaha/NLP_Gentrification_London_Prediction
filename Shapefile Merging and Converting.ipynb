# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# List of London borough names
london_boroughs = [
    "Barking and Dagenham", "Barnet", "Bexley", "Brent", "Bromley",
    "Camden", "City of London", "Croydon", "Ealing", "Enfield", "Greenwich",
    "Hackney", "Hammersmith and Fulham", "Haringey", "Harrow", "Havering",
    "Hillingdon", "Hounslow", "Islington", "Kensington and Chelsea", "Kingston upon Thames",
    "Lambeth", "Lewisham", "Merton", "Newham", "Redbridge",
    "Richmond upon Thames", "Southwark", "Sutton", "Tower Hamlets", "Waltham Forest",
    "Wandsworth", "Westminster"
    ]

# Directory where shapefiles are stored
shapefile_dir = "../Shapefile/LB_shp/"

# List to store successfully loaded shapefiles
valid_gdfs = []

for borough in london_boroughs:
    shp_file = f"{shapefile_dir}{borough}.shp"  # Keep borough name unchanged
    
    try:
        # Attempt to read shapefile
        gdf = gpd.read_file(shp_file)
        valid_gdfs.append(gdf)
        print(f"Successfully loaded: {shp_file}")
    except Exception as e:
        # Handle errors (e.g., file not found)
        print(f"Error: Failed to load {shp_file} - {e}")

# Merge all successfully loaded shapefiles
if valid_gdfs:
    london_lsoa = gpd.GeoDataFrame(pd.concat(valid_gdfs, ignore_index=True))
    # london_lsoa.to_file(f"{shapefile_dir}London_LSOA_Complete.shp")
    print("All boroughs merged successfully, saved as London_LSOA_Complete.shp")
else:
    print("No shapefiles loaded. Please check file paths and formats.")
# Out:
# Successfully loaded: ../Shapefile/LB_shp/Barking and Dagenham.shp
# Successfully loaded: ../Shapefile/LB_shp/Barnet.shp
# Successfully loaded: ../Shapefile/LB_shp/Bexley.shp
# Successfully loaded: ../Shapefile/LB_shp/Brent.shp
# Successfully loaded: ../Shapefile/LB_shp/Bromley.shp
# Successfully loaded: ../Shapefile/LB_shp/Camden.shp
# Successfully loaded: ../Shapefile/LB_shp/City of London.shp
# Successfully loaded: ../Shapefile/LB_shp/Croydon.shp
# Successfully loaded: ../Shapefile/LB_shp/Ealing.shp
# Successfully loaded: ../Shapefile/LB_shp/Enfield.shp
# Successfully loaded: ../Shapefile/LB_shp/Greenwich.shp
# Successfully loaded: ../Shapefile/LB_shp/Hackney.shp
# Successfully loaded: ../Shapefile/LB_shp/Hammersmith and Fulham.shp
# Successfully loaded: ../Shapefile/LB_shp/Haringey.shp
# Successfully loaded: ../Shapefile/LB_shp/Harrow.shp
# Successfully loaded: ../Shapefile/LB_shp/Havering.shp
# Successfully loaded: ../Shapefile/LB_shp/Hillingdon.shp
# Successfully loaded: ../Shapefile/LB_shp/Hounslow.shp
# Successfully loaded: ../Shapefile/LB_shp/Islington.shp
# Successfully loaded: ../Shapefile/LB_shp/Kensington and Chelsea.shp
# Successfully loaded: ../Shapefile/LB_shp/Kingston upon Thames.shp
# Successfully loaded: ../Shapefile/LB_shp/Lambeth.shp
# Successfully loaded: ../Shapefile/LB_shp/Lewisham.shp
# Successfully loaded: ../Shapefile/LB_shp/Merton.shp
# Successfully loaded: ../Shapefile/LB_shp/Newham.shp
# Successfully loaded: ../Shapefile/LB_shp/Redbridge.shp
# Successfully loaded: ../Shapefile/LB_shp/Richmond upon Thames.shp
# Successfully loaded: ../Shapefile/LB_shp/Southwark.shp
# Successfully loaded: ../Shapefile/LB_shp/Sutton.shp
# Successfully loaded: ../Shapefile/LB_shp/Tower Hamlets.shp
# Successfully loaded: ../Shapefile/LB_shp/Waltham Forest.shp
# Successfully loaded: ../Shapefile/LB_shp/Wandsworth.shp
# Successfully loaded: ../Shapefile/LB_shp/Westminster.shp
# All boroughs merged successfully, saved as London_LSOA_Complete.shp

# %%
fig, ax = plt.subplots(figsize=(10, 10))
london_lsoa.plot(ax=ax, edgecolor="black", linewidth=0.5, alpha=0.7, color="lightblue")
plt.show()

# %%
london_lsoa
# Out:
#        lsoa21cd                   lsoa21nm   msoa21cd  \
# 0     E01000011  Barking and Dagenham 016C  E02000017
# 1     E01000046  Barking and Dagenham 017D  E02000018
# 2     E01000051  Barking and Dagenham 021D  E02000022
# 3     E01000077  Barking and Dagenham 008F  E02000009
# 4     E01000083  Barking and Dagenham 007F  E02000008
# ...         ...                        ...        ...
# 4989  E01004727           Westminster 008D  E02000967
# 4990  E01035716           Westminster 013G  E02000972
# 4991  E01004731           Westminster 020A  E02000979
# 4992  E01004736           Westminster 018C  E02000977
# 4993  E01035718           Westminster 019G  E02000978
#
#                       msoa21nm    lad22cd               lad22nm  \
# 0     Barking and Dagenham 016  E09000002  Barking and Dagenham
# 1     Barking and Dagenham 017  E09000002  Barking and Dagenham
# 2     Barking and Dagenham 021  E09000002  Barking and Dagenham
# 3     Barking and Dagenham 008  E09000002  Barking and Dagenham
# 4     Barking and Dagenham 007  E09000002  Barking and Dagenham
# ...                        ...        ...                   ...
# 4989           Westminster 008  E09000033           Westminster
# 4990           Westminster 013  E09000033           Westminster
# 4991           Westminster 020  E09000033           Westminster
# 4992           Westminster 018  E09000033           Westminster
# 4993           Westminster 019  E09000033           Westminster
#
#                                                geometry
# 0     POLYGON ((544607.954 184727.846, 544620.667 18...
# 1     POLYGON ((547258.972 184378.376, 547259.861 18...
# 2     POLYGON ((544603.471 183903.184, 544620.396 18...
# 3     POLYGON ((547548.035 185377.027, 547545.923 18...
# 4     POLYGON ((547934.06 186229.42, 547931.391 1861...
# ...                                                 ...
# 4989  POLYGON ((527686.246 183502.219, 527697.728 18...
# 4990  POLYGON ((529365.209 181301.039, 529349.069 18...
# 4991  POLYGON ((529396.801 179907.419, 529469.883 17...
# 4992  POLYGON ((529666.73 180792.554, 529667.7 18079...
# 4993  POLYGON ((528044.949 180617.984, 528046.344 18...
#
# [4994 rows x 7 columns]

# %%
london_lsoa.crs
# Out:
# <Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.01, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
london_lsoa.columns
# Out:
# Index(['lsoa21cd', 'lsoa21nm', 'msoa21cd', 'msoa21nm', 'lad22cd', 'lad22nm',
#        'geometry'],
#       dtype='object')
