# %%
import pandas as pd

# %%
# Themes to load
themes = ["Tenure", "Ethnic_group", "Occupation", "Age_structure", "Education"]

# Base directories
data_dir_2011 = "../Dataset/Census London 2011/"
data_dir_2021 = "../Dataset/Census London 2021/"

# Merge key
merge_key = "LSOA21CD"

# Dictionary to store each theme's merged data
merged_data = {}

for theme in themes:
    # Construct file paths
    file_2011 = f"{data_dir_2011}{theme}_2011 mapping.csv"
    file_2021 = f"{data_dir_2021}{theme}_2021.csv"

    try:
        # Load data
        df_2011 = pd.read_csv(file_2011).dropna(axis=1, how="all")
        df_2021 = pd.read_csv(file_2021).dropna(axis=1, how="all")

        # Remove 'Borough' column from 2021 data if it exists
        if "Borough" in df_2021.columns:
            df_2021.drop(columns=["Borough"], inplace=True)

        # Add suffixes to all columns except the merge key
        df_2011 = df_2011.rename(columns={col: col + "_2011" for col in df_2011.columns if col != merge_key})
        df_2021 = df_2021.rename(columns={col: col + "_2021" for col in df_2021.columns if col != merge_key})

        # Merge 2011 and 2021 data for this theme
        df_merged = pd.merge(df_2011, df_2021, on=merge_key, how="outer")

        # Store result
        merged_data[theme] = df_merged

        print(f"Successfully loaded and merged: {theme}")

    except Exception as e:
        print(f"Error processing {theme}: {e}")


# Combine all themes into a single DataFrame
df_census = list(merged_data.values())[0]
for df in list(merged_data.values())[1:]:
    df_census = pd.merge(df_census, df, on=merge_key, how="outer")
# Out:
# Successfully loaded and merged: Tenure
# Successfully loaded and merged: Ethnic_group
# Successfully loaded and merged: Occupation
# Successfully loaded and merged: Age_structure
# Successfully loaded and merged: Education

# %%
df_property_sales = pd.read_csv("../Output/Number of sales mapping.csv")

# %%
df_census = df_census.merge(df_property_sales, left_on='LSOA21CD', right_on='LSOA21CD')

# %%
df_census
# Out:
#        LSOA21CD  All households_weighted_2011  Owned_weighted_2011  \
# 0     E01000001                         876.0                533.0
# 1     E01000002                         830.0                527.0
# 2     E01000003                         817.0                327.0
# 3     E01000005                         467.0                 46.0
# 4     E01000006                         543.0                345.0
# ...         ...                           ...                  ...
# 4989  E01035718                         996.0                502.0
# 4990  E01035719                         528.0                193.0
# 4991  E01035720                         597.0                218.0
# 4992  E01035721                        1296.0                294.0
# 4993  E01035722                        1672.0                319.0
#
#       Owned: Owned outright_weighted_2011  \
# 0                                   355.0
# 1                                   314.0
# 2                                   184.0
# 3                                    24.0
# 4                                   136.0
# ...                                   ...
# 4989                                380.0
# 4990                                103.0
# 4991                                117.0
# 4992                                186.0
# 4993                                201.0
#
#       Owned: Owned with a mortgage or loan_weighted_2011  \
# 0                                                 178.0
# 1                                                 213.0
# 2                                                 143.0
# 3                                                  22.0
# 4                                                 209.0
# ...                                                 ...
# 4989                                              122.0
# 4990                                               90.0
# 4991                                              101.0
# 4992                                              108.0
# 4993                                              118.0
#
#       Shared ownership (part owned and part rented)_weighted_2011  \
# 0                                                   3.0
# 1                                                   8.0
# 2                                                   1.0
# 3                                                   0.0
# 4                                                   0.0
# ...                                                 ...
# 4989                                                4.0
# 4990                                               10.0
# 4991                                               12.0
# 4992                                               19.0
# 4993                                                0.0
#
#       Social rented_weighted_2011  \
# 0                            41.0
# 1                            48.0
# 2                           295.0
# 3                           312.0
# 4                            18.0
# ...                           ...
# 4989                         44.0
# 4990                        156.0
# 4991                        176.0
# 4992                        601.0
# 4993                        150.0
#
#       Social rented: Rented from council (Local Authority)_weighted_2011  \
# 0                                                  33.0
# 1                                                  44.0
# 2                                                 239.0
# 3                                                 133.0
# 4                                                  11.0
# ...                                                 ...
# 4989                                                7.0
# 4990                                               95.0
# 4991                                              107.0
# 4992                                              272.0
# 4993                                               26.0
#
#       Social rented: Other_weighted_2011  Private rented_weighted_2011  ...  \
# 0                                    8.0                         264.0  ...
# 1                                    4.0                         219.0  ...
# 2                                   56.0                         177.0  ...
# 3                                  179.0                         101.0  ...
# 4                                    7.0                         178.0  ...
# ...                                  ...                           ...  ...
# 4989                                37.0                         363.0  ...
# 4990                                61.0                         151.0  ...
# 4991                                69.0                         170.0  ...
# 4992                               329.0                         362.0  ...
# 4993                               124.0                        1172.0  ...
#
#       Total: All usual residents aged 16 years and over_2021  \
# 0                                                  1353
# 1                                                  1298
# 2                                                  1505
# 3                                                   961
# 4                                                  1433
# ...                                                 ...
# 4989                                               2306
# 4990                                               1100
# 4991                                               1064
# 4992                                               2020
# 4993                                               1871
#
#       No qualifications_2021  Level 1 and entry level qualifications_2021  \
# 0                       32.0                                         27.0
# 1                       23.0                                         28.0
# 2                      132.0                                         61.0
# 3                      197.0                                         64.0
# 4                      295.0                                        158.0
# ...                      ...                                          ...
# 4989                    87.0                                         60.0
# 4990                    84.0                                         38.0
# 4991                   111.0                                         51.0
# 4992                   262.0                                        108.0
# 4993                   175.0                                         60.0
#
#       Level 2 qualifications_2021  Apprenticeship_2021  \
# 0                            53.0                 12.0
# 1                            52.0                  4.0
# 2                            90.0                 12.0
# 3                           120.0                 32.0
# 4                           170.0                 39.0
# ...                           ...                  ...
# 4989                        122.0                 64.0
# 4990                         75.0                 21.0
# 4991                         95.0                 13.0
# 4992                        157.0                 50.0
# 4993                         97.0                 51.0
#
#       Level 3 qualifications_2021  Level 4 qualifications or above_2021  \
# 0                            86.0                                1127.0
# 1                            87.0                                1086.0
# 2                           120.0                                1055.0
# 3                           131.0                                 387.0
# 4                           204.0                                 501.0
# ...                           ...                                   ...
# 4989                        792.0                                1084.0
# 4990                        113.0                                 731.0
# 4991                        157.0                                 612.0
# 4992                        303.0                                1101.0
# 4993                        212.0                                1231.0
#
#       Other qualifications_2021  Number of sales 2011_weighted  \
# 0                          16.0                          141.0
# 1                          18.0                          233.0
# 2                          35.0                          168.0
# 3                          30.0                           41.0
# 4                          66.0                           44.0
# ...                         ...                            ...
# 4989                       97.0                          189.0
# 4990                       38.0                           75.0
# 4991                       25.0                           84.0
# 4992                       39.0                          100.0
# 4993                       45.0                          112.0
#
#       Number of sales 2021_weighted
# 0                             123.0
# 1                             144.0
# 2                              95.0
# 3                              10.0
# 4                              58.0
# ...                             ...
# 4989                          113.0
# 4990                           41.0
# 4991                           46.0
# 4992                           89.0
# 4993                           99.0
#
# [4994 rows x 144 columns]

# %%
print(df_census.columns.to_list())
# Out:
# ['LSOA21CD', 'All households_weighted_2011', 'Owned_weighted_2011', 'Owned: Owned outright_weighted_2011', 'Owned: Owned with a mortgage or loan_weighted_2011', 'Shared ownership (part owned and part rented)_weighted_2011', 'Social rented_weighted_2011', 'Social rented: Rented from council (Local Authority)_weighted_2011', 'Social rented: Other_weighted_2011', 'Private rented_weighted_2011', 'Private rented: Private landlord or letting agency_weighted_2011', 'Private rented: Other_weighted_2011', 'Living rent free_weighted_2011', 'Total: All households_2021', 'Owned_2021', 'Owned: Owns outright_2021', 'Owned: Owns with a mortgage or loan_2021', 'Shared ownership_2021', 'Shared ownership: Shared ownership_2021', 'Social rented_2021', 'Social rented: Rents from council or Local Authority_2021', 'Social rented: Other social rented_2021', 'Private rented_2021', 'Private rented: Private landlord or letting agency_2021', 'Private rented: Other private rented_2021', 'Lives rent free_2021', 'Owns with a mortgage or loan or shared ownership_2021', 'Private rented or lives rent free_2021', 'All usual residents_weighted_2011', 'White_weighted_2011', 'White: English/Welsh/Scottish/Northern Irish/British_weighted_2011', 'White: Irish_weighted_2011', 'White: Gypsy or Irish Traveller_weighted_2011', 'White: Other White_weighted_2011', 'Mixed/multiple ethnic groups_weighted_2011', 'Mixed/multiple ethnic groups: White and Black Caribbean_weighted_2011', 'Mixed/multiple ethnic groups: White and Black African_weighted_2011', 'Mixed/multiple ethnic groups: White and Asian_weighted_2011', 'Mixed/multiple ethnic groups: Other Mixed_weighted_2011', 'Asian/Asian British_weighted_2011', 'Asian/Asian British: Indian_weighted_2011', 'Asian/Asian British: Pakistani_weighted_2011', 'Asian/Asian British: Bangladeshi_weighted_2011', 'Asian/Asian British: Chinese_weighted_2011', 'Asian/Asian British: Other Asian_weighted_2011', 'Black/African/Caribbean/Black British_weighted_2011', 'Black/African/Caribbean/Black British: African_weighted_2011', 'Black/African/Caribbean/Black British: Caribbean_weighted_2011', 'Black/African/Caribbean/Black British: Other Black_weighted_2011', 'Other ethnic group_weighted_2011', 'Other ethnic group: Arab_weighted_2011', 'Other ethnic group: Any other ethnic group_weighted_2011', 'Total: All usual residents_2021', 'Asian, Asian British or Asian Welsh_2021', 'Asian, Asian British or Asian Welsh: Bangladeshi_2021', 'Asian, Asian British or Asian Welsh: Chinese_2021', 'Asian, Asian British or Asian Welsh: Indian_2021', 'Asian, Asian British or Asian Welsh: Pakistani_2021', 'Asian, Asian British or Asian Welsh: Other Asian_2021', 'Black, Black British, Black Welsh, Caribbean or African_2021', 'Black, Black British, Black Welsh, Caribbean or African: African_2021', 'Black, Black British, Black Welsh, Caribbean or African: Caribbean_2021', 'Black, Black British, Black Welsh, Caribbean or African: Other Black_2021', 'Mixed or Multiple ethnic groups_2021', 'Mixed or Multiple ethnic groups: White and Asian_2021', 'Mixed or Multiple ethnic groups: White and Black African_2021', 'Mixed or Multiple ethnic groups: White and Black Caribbean_2021', 'Mixed or Multiple ethnic groups: Other Mixed or Multiple ethnic groups_2021', 'White_2021', 'White: English, Welsh, Scottish, Northern Irish or British_2021', 'White: Irish_2021', 'White: Gypsy or Irish Traveller_2021', 'White: Roma_2021', 'White: Other White_2021', 'Other ethnic group_2021', 'Other ethnic group: Arab_2021', 'Other ethnic group: Any other ethnic group_2021', 'All categories: Occupation_weighted_2011', '1. Managers, directors and senior officials_weighted_2011', '2. Professional occupations_weighted_2011', '3. Associate professional and technical occupations_weighted_2011', '4. Administrative and secretarial occupations_weighted_2011', '5. Skilled trades occupations_weighted_2011', '6. Caring, leisure and other service occupations_weighted_2011', '7. Sales and customer service occ ...

# %%
df_census['pct_high_education_2011'] = df_census['Highest level of qualification: Level 4 qualifications and above_weighted_2011'] / df_census['All categories: Highest level of qualification_weighted_2011']
df_census['pct_high_education_2021'] = df_census['Level 4 qualifications or above_2021'] / df_census['Total: All usual residents aged 16 years and over_2021']
df_census['delta_high_education'] = df_census['pct_high_education_2021'] - df_census['pct_high_education_2011']

# %%
df_census['pct_owner_occupied_2011'] = df_census['Owned_weighted_2011']  / df_census['All households_weighted_2011']
df_census['pct_owner_occupied_2021'] = df_census['Owned_2021']  / df_census['Total: All households_2021']
df_census['delta_owner_occupied'] = df_census['pct_owner_occupied_2021'] - df_census['pct_owner_occupied_2011']

# %%
df_census['pct_private_rented_2011'] = df_census['Private rented_weighted_2011']  / df_census['All households_weighted_2011']
df_census['pct_private_rented_2021'] = df_census['Private rented_2021']  / df_census['Total: All households_2021']
df_census['delta_private_rented'] = df_census['pct_private_rented_2021'] - df_census['pct_private_rented_2011']

# %%
df_census['pct_social_rented_2011'] = df_census['Social rented_weighted_2011'] / df_census['All households_weighted_2011']
df_census['pct_social_rented_2021'] = df_census['Social rented_2021'] / df_census['Total: All households_2021']
df_census['delta_social_rented'] = df_census['pct_social_rented_2021'] - df_census['pct_social_rented_2011']

# %%
df_census['pct_renters_2011'] = df_census['pct_social_rented_2011'] + df_census['pct_private_rented_2011']
df_census['pct_renters_2021'] = df_census['pct_social_rented_2021'] + df_census['pct_private_rented_2021']
df_census['delta_renters'] = df_census['pct_renters_2021'] - df_census['pct_renters_2011']

# %%
df_census['pct_professional_2011'] = (df_census['1. Managers, directors and senior officials_weighted_2011'] + 
                                      df_census['2. Professional occupations_weighted_2011']) / df_census['All categories: Occupation_weighted_2011']
df_census['pct_professional_2021'] = (df_census['1. Managers, directors and senior officials_2021'] + df_census['2. Professional occupations_2021']) / df_census['Total: All usual residents aged 16 years and over in employment the week before the census_2021']
df_census['delta_professional'] = df_census['pct_professional_2021'] - df_census['pct_professional_2011']

# %%
df_census['pct_low_skill_2011'] = (df_census['8. Process plant and machine operatives_weighted_2011'] +
                                   df_census['9. Elementary occupations_weighted_2011']) / df_census['All categories: Occupation_weighted_2011']
df_census['pct_low_skill_2021'] = (df_census['8. Process, plant and machine operatives_2021'] +
                                   df_census['9. Elementary occupations_2021']) / df_census['Total: All usual residents aged 16 years and over in employment the week before the census_2021']
df_census['delta_low_skill'] = df_census['pct_low_skill_2021'] - df_census['pct_low_skill_2011']

# %%
df_census['age_20_29_2011'] = (df_census['Age 25 to 29_weighted_2011'] + 
                               df_census['Age 20 to 24_weighted_2011']) / df_census['All usual residents_weighted_2011']
df_census['age_20_29_2021'] = (df_census['Aged 25 to 29 years_2021'] + 
                               df_census['Aged 20 to 24 years_2021']) / df_census['Total: All usual residents_2021']
df_census['delta_age_20_29'] = df_census['age_20_29_2021'] - df_census['age_20_29_2011']

# %%
df_census['pct_minority_ethnic_2011'] = (df_census['Mixed/multiple ethnic groups_weighted_2011'] + 
                                         df_census['Asian/Asian British_weighted_2011'] + 
                                         df_census['Black/African/Caribbean/Black British_weighted_2011'] + 
                                         df_census['Other ethnic group_weighted_2011']) / df_census['All usual residents_weighted_2011']
df_census['pct_minority_ethnic_2021'] = (df_census['Mixed or Multiple ethnic groups_2021'] + 
                                         df_census['Asian, Asian British or Asian Welsh_2021'] + 
                                         df_census['Black, Black British, Black Welsh, Caribbean or African_2021'] + 
                                         df_census['Other ethnic group_2021']) / df_census['Total: All usual residents_2021']
df_census['delta_minority_ethnic'] = df_census['pct_minority_ethnic_2021'] - df_census['pct_minority_ethnic_2011']

# %%
df_census['delta_property_sales'] = df_census['Number of sales 2021_weighted'] - df_census['Number of sales 2011_weighted']

# %%
df_census = df_census[['LSOA21CD', 
                'delta_age_20_29', 'delta_property_sales', 
                'pct_minority_ethnic_2011', 'pct_minority_ethnic_2021', 'delta_minority_ethnic',
                'pct_professional_2011', 'pct_professional_2021', 'delta_professional', 
                'pct_owner_occupied_2011', 'pct_owner_occupied_2021', 'delta_owner_occupied',
                'pct_social_rented_2011', 'pct_social_rented_2021', 'delta_social_rented',
                'pct_private_rented_2011', 'pct_private_rented_2021', 'delta_private_rented',
                'pct_renters_2011', 'pct_renters_2021', 'delta_renters',
                'pct_high_education_2011','pct_high_education_2021','delta_high_education',
                'pct_low_skill_2011', 'pct_low_skill_2021', 'delta_low_skill']]

# %%
df_census
# Out:
#        LSOA21CD  delta_age_20_29  delta_property_sales  \
# 0     E01000001         0.030362                 -18.0
# 1     E01000002         0.099997                 -89.0
# 2     E01000003         0.011368                 -73.0
# 3     E01000005        -0.027058                 -31.0
# 4     E01000006        -0.064914                  14.0
# ...         ...              ...                   ...
# 4989  E01035718        -0.024713                 -76.0
# 4990  E01035719         0.045407                 -34.0
# 4991  E01035720         0.058255                 -38.0
# 4992  E01035721        -0.021252                 -11.0
# 4993  E01035722         0.031326                 -13.0
#
#       pct_minority_ethnic_2011  pct_minority_ethnic_2021  \
# 0                     0.154949                  0.198779
# 1                     0.112813                  0.217893
# 2                     0.216196                  0.258685
# 3                     0.486294                  0.614896
# 4                     0.672930                  0.672087
# ...                        ...                       ...
# 4989                  0.364393                  0.378410
# 4990                  0.239919                  0.369497
# 4991                  0.239750                  0.345111
# 4992                  0.324357                  0.439863
# 4993                  0.164505                  0.340288
#
#       delta_minority_ethnic  pct_professional_2011  pct_professional_2021  \
# 0                  0.043830               0.661987               0.688431
# 1                  0.105080               0.646154               0.723235
# 2                  0.042489               0.489529               0.580000
# 3                  0.128601               0.273109               0.366397
# 4                 -0.000843               0.256082               0.226607
# ...                     ...                    ...                    ...
# 4989               0.014017               0.492778               0.572354
# 4990               0.129578               0.516755               0.583824
# 4991               0.105360               0.515625               0.485337
# 4992               0.115505               0.366980               0.495814
# 4993               0.175783               0.534215               0.624576
#
#       delta_professional  pct_owner_occupied_2011  ...  delta_private_rented  \
# 0               0.026444                 0.608447  ...              0.091701
# 1               0.077081                 0.634940  ...              0.176823
# 2               0.090471                 0.400245  ...              0.111433
# 3               0.093288                 0.098501  ...              0.001299
# 4              -0.029475                 0.635359  ...              0.136929
# ...                  ...                      ...  ...                   ...
# 4989            0.079576                 0.504016  ...              0.147837
# 4990            0.067069                 0.365530  ...              0.099481
# 4991           -0.030288                 0.365159  ...              0.022023
# 4992            0.128834                 0.226852  ...              0.026723
# 4993            0.090361                 0.190789  ...             -0.026381
#
#       pct_renters_2011  pct_renters_2021  delta_renters  \
# 0             0.348174          0.419355       0.071181
# 1             0.321687          0.473366       0.151679
# 2             0.577723          0.625616       0.047892
# 3             0.884368          0.914226       0.029858
# 4             0.360958          0.504521       0.143563
# ...                ...               ...            ...
# 4989          0.408635          0.538251       0.129617
# 4990          0.581439          0.647709       0.066270
# 4991          0.579564          0.718644       0.139080
# 4992          0.743056          0.789594       0.046539
# 4993          0.790670          0.811017       0.020347
#
#       pct_high_education_2011  pct_high_education_2021  delta_high_education  \
# 0                    0.775556                 0.832964              0.057408
# 1                    0.791957                 0.836672              0.044715
# 2                    0.568438                 0.700997              0.132559
# 3                    0.344702                 0.402706              0.058004
# 4                    0.329259                 0.349616              0.020357
# ...                       ...                      ...                   ...
# 4989                 0.366227                 0.470078              0.103852
# 4990                 0.572254                 0.664545              0.092291
# 4991                 0.572597                 0.575188              0.002591
# 4992                 0.436606                 0.545050              0.108443
# 4993                 0.641118                 0.657937              0.016819
#
#       pct_low_skill_2011  pct_low_skill_2021  delta_low_skill
# 0               0.015119            0.011455        -0.003664
# 1               0.017582            0.011390        -0.006193
# 2               0.073298            0.052000        -0.021298
# 3               0.199580            0.206478         0.006898
# 4               0.226633            0.295378         0.068745
# ...                  ...                 ...              ...
# 4989            0.058624            0.053996        -0.004628
# 4990            0.049383            0.045588        -0.003794
# 4991            0.050000            0.096774         0.046774
# 4992            0.107199            0.080930        -0.026269
# 4993            0.032202            0.034746         0.002543
#
# [4994 rows x 27 columns]

# %%
df_census.to_csv("../Output/data for gentrification classification_.csv", index=False)
