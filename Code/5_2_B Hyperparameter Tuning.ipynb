# %%
import random
import numpy as np

random.seed(42)
np.random.seed(42)

import pandas as pd

import matplotlib.pyplot as plt

# %%
embeddings_s = np.load('../Model/emb_s_all-MiniLM-L6-v2.npy')

description_text_s = pd.read_csv('../Output/london_app_s_doc.csv')

# %%
docs_s = description_text_s['description'].tolist()

# %%
def compute_diversity_score(topic_model):
    """
    Compute topic diversity score as the ratio of unique keywords 
    to total keywords across all topics (excluding topic -1).
    """
    topics_ = topic_model.get_topics()
    all_words = [
        word for topic_id, words in topics_.items() if topic_id != -1
        for word, _ in words
    ]
    unique_words = set(all_words)
    return len(unique_words) / len(all_words) if all_words else 0

# %%
import re
from gensim.corpora import Dictionary
from gensim.models import CoherenceModel

def compute_coherence_score(
    topic_model,
    docs, 
    top_n_words = 10,
    coherence = 'c_v'
):

    # Tokenize documents with a clean, custom tokenizer
    def clean_tokenizer(doc):
        return re.findall(r'\b[a-zA-Z][a-zA-Z0-9\-]{2,}\b', doc.lower())

    tokenized_docs = [clean_tokenizer(doc) for doc in docs if isinstance(doc, str) and doc.strip()]

    # Build gensim Dictionary
    dictionary = Dictionary(tokenized_docs)

    # Restrict to vectorizer's vocabulary
    vectorizer = topic_model.vectorizer_model
    vocab = set(vectorizer.get_feature_names_out())

    # Extract top words from each topic, filtering out -1
    topic_words = []
    for topic_id in topic_model.get_topic_info().Topic.tolist():
        if topic_id == -1:
            continue
        words = [w for w, _ in topic_model.get_topic(topic_id)[:top_n_words]]
        filtered = [w for w in words if w in vocab and w in dictionary.token2id]
        if filtered:
            topic_words.append(filtered)

    # Compute coherence
    coherence_model = CoherenceModel(
        topics=topic_words,
        texts=tokenized_docs,
        dictionary=dictionary,
        coherence=coherence
    )

    return coherence_model.get_coherence()

# %%
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN

from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
import itertools

def Bertopic_tuning(param_grid):
    
    # Get all combinations
    raw_combinations = list(itertools.product(*param_grid.values()))

    # Filter only keep valid combinations where min_samples <= min_cluster_size
    valid_combinations = [
        (nn, dist, mcs, ms, ngram)
        for nn, dist, mcs, ms, ngram in raw_combinations
        if ms <= mcs
    ]

    results = []

    for nn, dist, mcs, ms, ngram in valid_combinations:

        print(f"Testing: n_neighbors={nn}, min_dist={dist}, min_cluster_size={mcs}, min_samples={ms}, ngram_range={ngram}")

        umap_model = UMAP(
            n_neighbors=nn, 
            n_components=5, 
            min_dist=dist, 
            metric='cosine',
            random_state=42
        )
        
        hdbscan_model = HDBSCAN(
            min_cluster_size=mcs,
            min_samples=ms,
            prediction_data=True
        )
        
        vectorizer_model = CountVectorizer(ngram_range=ngram)

        topic_model = BERTopic(
            embedding_model=embedding_model,
            umap_model=umap_model,
            hdbscan_model=hdbscan_model,
            vectorizer_model=vectorizer_model,
            calculate_probabilities=False,
            verbose=False,
            top_n_words=10
        )

        topics, _ = topic_model.fit_transform(docs_s, embeddings=embeddings_s)
        coherence = compute_coherence_score(topic_model, docs_s)
        diversity = compute_diversity_score(topic_model)
        outlier_ratio = sum([1 for t in topics if t == -1]) / len(topics)

        results.append({
            'n_neighbors': nn,
            'min_dist': dist,
            'min_cluster_size': mcs,
            'min_samples': ms,
            'ngram_range': str(ngram),
            'coherence': coherence,
            'diversity': diversity,
            'outlier_ratio': outlier_ratio
        })
        
    return pd.DataFrame(results)

# %%
param_grid = {
    "n_neighbors": [10, 15, 30],
    "min_dist": [0.0, 0.1, 0.3],
    "min_cluster_size": [10, 15, 30],
    "min_samples": [5, 10, 15],
    "ngram_range": [(1, 1), (1, 2)]
}

df_results = Bertopic_tuning(param_grid)
df_results.to_csv("../Output/Performance (Bertopic) First stage.csv", index=False)
# Out:
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.1, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=10, min_dist=0.3, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.1, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=15, min_dist=0.3, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.1, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=10, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=10, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=15, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=15, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=15, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=30, min_samples=5, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=30, min_samples=10, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=30, min_samples=15, ngram_range=(1, 1)
# Testing: n_neighbors=30, min_dist=0.3, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 6))

ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df_results['coherence'], df_results['diversity'], df_results['outlier_ratio'],
                c=df_results['coherence'], cmap='viridis', s=60)
ax.set_xlabel('Coherence')
ax.set_ylabel('Diversity')
ax.set_zlabel('Outlier Ratio')

plt.title("BERTopic Hyperparameter Tuning Results")
plt.colorbar(sc, label='Coherence Score')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_single_hyperparam(df, hyperparam: str):
    """
    Visualize how a single hyperparameter affects key evaluation metrics 
    (coherence, diversity, outlier_ratio) in BERTopic tuning.

    Parameters:
    - df: DataFrame containing tuning results
    - hyperparam: the name of the hyperparameter to analyze (e.g., "min_cluster_size")
    """

    # Group by the hyperparameter and compute mean of each metric
    df_grouped = df.groupby(hyperparam).agg({
        'coherence': 'mean',
        'diversity': 'mean',
        'outlier_ratio': 'mean',
        'performance': 'mean'
    }).reset_index()

    # Sort for consistent line plot
    df_grouped.sort_values(by=hyperparam, inplace=True)

    # Plot the effect of the hyperparameter on each metric
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.plot(df_grouped[hyperparam], df_grouped['coherence'], marker='o', label='Coherence')
    ax.plot(df_grouped[hyperparam], df_grouped['diversity'], marker='o', label='Diversity')
    ax.plot(df_grouped[hyperparam], df_grouped['outlier_ratio'], marker='o', label='Outlier Ratio')
    ax.plot(df_grouped[hyperparam], df_grouped['performance'], marker='o', label='Performance')

    ax.set_xlabel(hyperparam, fontsize=12, fontweight='bold')
    ax.set_ylabel("Score", fontsize=12, fontweight='bold')
    ax.set_title(f"Effect of '{hyperparam}' on BERTopic Performance", fontsize=16, fontweight='bold',pad=20)
    ax.legend()
    ax.grid(True)
    plt.tight_layout()
    plt.show()

# %%
def plot_all_hyperparams(df, metric_names=['coherence', 'diversity', 'outlier_ratio']):
    """
    Plot the effect of each numeric hyperparameter on model metrics

    Parameters:
    - df: tuning results DataFrame
    - metric_names: list of evaluation metrics to exclude from hyperparameter list
    """
    all_columns = df.columns.tolist()
    
    hyperparams = [col for col in all_columns if col not in metric_names + ['ngram_range']]
    numeric_hyperparams = [param for param in hyperparams if np.issubdtype(df[param].dtype, np.number)]

    # Define colors per metric
    metric_colors = {
        'coherence': 'tab:blue',
        'diversity': 'tab:green',
        'outlier_ratio': 'tab:red'
    }

    # Define line styles per ngram_range
    line_styles = {
        '(1, 1)': 'solid',
        '(1, 2)': 'dashed'
    }

    total = len(numeric_hyperparams)
    ncols = (total + 1) // 2
    fig, axs = plt.subplots(2, ncols, figsize=(9 * ncols, 12), squeeze=False)

    for i, param in enumerate(numeric_hyperparams):
        row = i % 2
        col = i // 2
        ax = axs[row][col]

        for ngram in df['ngram_range'].unique():
            df_subset = df[df['ngram_range'] == ngram]
            ngram_str = str(ngram)
            linestyle = line_styles.get(ngram_str, 'solid')

            df_grouped = df_subset.groupby(param).agg({
                'coherence': 'mean',
                'diversity': 'mean',
                'outlier_ratio': 'mean'
            }).reset_index().sort_values(by=param)

            for metric in metric_names:
                ax.plot(
                    df_grouped[param],
                    df_grouped[metric],
                    label=f"{metric.title()} (ngram={ngram})",
                    linestyle=linestyle,
                    color=metric_colors[metric]
                )

        ax.set_title(f"{param}", fontsize=12, fontweight='bold')
        ax.set_xlabel(param)
        ax.set_ylabel("Score")
        ax.grid(True)

    if total % 2 == 1:
        axs[1][-1].axis('off')

    import matplotlib.lines as mlines

    # Create custom legends
    color_legend = [
        mlines.Line2D([], [], color='tab:blue', linestyle='solid', label='Coherence'),
        mlines.Line2D([], [], color='tab:green', linestyle='solid', label='Diversity'),
        mlines.Line2D([], [], color='tab:red', linestyle='solid', label='Outlier Ratio')
    ]

    style_legend = [
        mlines.Line2D([], [], color='black', linestyle='solid', label='ngram = (1, 1)'),
        mlines.Line2D([], [], color='black', linestyle='dashed', label='ngram = (1, 2)')
    ]

    plt.tight_layout()

    # At the end of the loop, add legends once
    fig.legend(handles=color_legend, loc='upper center', bbox_to_anchor=(0.4, 0.75), ncol=3, title="Model Performance")
    fig.legend(handles=style_legend, loc='lower center', bbox_to_anchor=(0.4, 0.65), ncol=2, title="Ngram Range")

    plt.suptitle("Effect of BERTopic Hyperparameters", fontsize=16, fontweight='bold', y=1.03)
    plt.subplots_adjust(top=0.95)  
    plt.show()

# %%
plot_all_hyperparams(df_results)

# %%
param_grid_plus = {
    "n_neighbors": [10, 15, 30],
    "min_dist": [0.0],
    "min_cluster_size": [10, 15, 20, 25, 30],
    "min_samples": [5, 10, 15, 20, 25],
    "ngram_range": [(1, 2)]
}

df_results_plus = Bertopic_tuning(param_grid_plus)
df_results_plus.to_csv("../Output/Performance (Bertopic) Second stage.csv", index=False)
# Out:
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=20, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=20, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=20, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=20, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=25, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=25, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=25, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=25, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=25, min_samples=25, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=30, min_samples=25, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=20, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=20, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=20, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=20, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=25, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=25, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=25, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=25, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=25, min_samples=25, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=30, min_samples=25, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=15, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=20, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=20, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=20, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=20, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=25, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=25, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=25, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=25, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=25, min_samples=25, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=10, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=15, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=20, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=30, min_samples=25, ngram_range=(1, 2)

# %%
import seaborn as sns

n_neighbors_list = [10, 15, 30]
metrics = ['coherence', 'diversity', 'outlier_ratio']

for n in n_neighbors_list:
    df_subset = df_results_plus[df_results_plus['n_neighbors'] == n]

    fig, axes = plt.subplots(1, 3, figsize=(21, 6))
    for i, metric in enumerate(metrics):
        pivot = df_subset.pivot_table(
            index='min_cluster_size',
            columns='min_samples',
            values=metric,
            aggfunc='mean'
        )

        sns.heatmap(
            pivot,
            annot=True,
            fmt=".4f",
            cmap='YlGnBu',
            ax=axes[i]
        )

        axes[i].set_title(f"{metric.title()} (n_neighbors={n})", fontsize=12)
        axes[i].set_xlabel("min_samples")
        axes[i].set_ylabel("min_cluster_size")

    plt.tight_layout()
    plt.suptitle(f"BERTopic Metrics by min_cluster_size × min_samples (n_neighbors={n})", fontsize=16, fontweight='bold', y=1.05)
    plt.show()

# %%
param_grid_final = {
    "n_neighbors": [10, 15, 20, 25, 30],
    "min_dist": [0.0],
    "min_cluster_size": [10],
    "min_samples": [5],
    "ngram_range": [(1, 2)]
}

df_results_final = Bertopic_tuning(param_grid_final)
df_results_final.to_csv("../Output/Performance (Bertopic) Final stage.csv", index=False)
# Out:
# Testing: n_neighbors=10, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=15, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=20, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=25, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)
# Testing: n_neighbors=30, min_dist=0.0, min_cluster_size=10, min_samples=5, ngram_range=(1, 2)

# %%
df_results_final
# Out:
#    n_neighbors  min_dist  min_cluster_size  min_samples ngram_range  \
# 0           10       0.0                10            5      (1, 2)
# 1           15       0.0                10            5      (1, 2)
# 2           20       0.0                10            5      (1, 2)
# 3           25       0.0                10            5      (1, 2)
# 4           30       0.0                10            5      (1, 2)
#
#    coherence  diversity  outlier_ratio  performance
# 0   0.803425   0.515714         0.3025     1.319140
# 1   0.793990   0.526374         0.3281     1.320364
# 2   0.801687   0.509392         0.3379     1.311079
# 3   0.786623   0.527517         0.3336     1.314140
# 4   0.802096   0.515385         0.3572     1.317481

# %%
df_results_final['performance'] = df_results_final['coherence'] + df_results_final['diversity']
plot_single_hyperparam(df_results_final, 'n_neighbors')
